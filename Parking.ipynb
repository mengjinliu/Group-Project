# %%
import pandas as pd
import csv
import numpy as np

# %%
df = pd.read_csv('311_Service_Requests_2020.csv')
# Out:
# /Users/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2587316 entries, 0 to 2587315
# Data columns (total 41 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Unique Key                      int64
#  1   Created Date                    object
#  2   Closed Date                     object
#  3   Agency                          object
#  4   Agency Name                     object
#  5   Complaint Type                  object
#  6   Descriptor                      object
#  7   Location Type                   object
#  8   Incident Zip                    float64
#  9   Incident Address                object
#  10  Street Name                     object
#  11  Cross Street 1                  object
#  12  Cross Street 2                  object
#  13  Intersection Street 1           object
#  14  Intersection Street 2           object
#  15  Address Type                    object
#  16  City                            object
# ...

# %%
df1= df[df['Incident Zip']==10025]
df1
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 11         45278238  01/01/2020 12:01:46 AM  01/01/2020 05:37:46 AM   NYPD
# 141        45278928  01/01/2020 12:36:42 AM  01/01/2020 01:19:30 AM   NYPD
# 463        45282069  01/01/2020 01:37:02 AM  01/01/2020 01:55:21 AM   NYPD
# 979        45286989  01/01/2020 03:33:15 AM  02/21/2020 08:45:41 AM    TLC
# 1166       45287132  01/01/2020 04:33:27 AM  01/03/2020 05:46:11 AM    HPD
# ...             ...                     ...                     ...    ...
# 2586233    48532983  12/30/2020 08:11:19 PM  01/01/2021 06:35:12 PM    HPD
# 2586442    48531180  12/30/2020 08:55:03 PM  12/30/2020 09:48:13 PM   NYPD
# 2586758    48535864  12/30/2020 10:05:50 PM  01/12/2021 11:58:43 AM  DOHMH
# 2586833    48532767  12/30/2020 10:18:40 PM  12/30/2020 10:28:10 PM   NYPD
# 2586908    48533796  12/30/2020 10:35:52 PM  12/30/2020 10:52:44 PM   NYPD
#
#                                                Agency Name  \
# ...

# %%
# n_1: illegal parking number in Zip10025
df2 = df1[df1['Complaint Type']=='Illegal Parking']
n_1 = pd.DataFrame(df2).shape[0]

# n_2: total number of all incidents in Zip10025
n_2 = pd.DataFrame(df1).shape[0]

frc_1 = n_1 / n_2
frc_1
# Out:
# 0.03775383735341787

# %%
df3= df[df['Complaint Type']=='Illegal Parking']

# n_3: illegal parking number in NYC
n_3 = pd.DataFrame(df3).shape[0]

# n_4: total number of all incidents in NYC
n_4 = pd.DataFrame(df).shape[0]

frc_2 = n_3 / n_4
frc_2
# Out:
# 0.07487334365033108

# %%
higher_parking_proportion = frc_1 > frc_2
higher_parking_proportion
# Out:
# False
